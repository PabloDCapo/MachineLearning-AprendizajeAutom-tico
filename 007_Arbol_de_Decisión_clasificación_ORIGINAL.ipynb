# %% [markdown]
# # Machine Learning
#
# ## Aprendizaje Supervisado - Clasificación
#
# En este notebook, comenzamos a trabajar en los problemas de **Clasificación**, una de las tareas más importantes dentro de Machine Learning (dentro, a su vez, de lo que llamamos Aprendizaje Supervisado). Clasificación en Machine Learning consiste en aprender etiquetas discretas *y* a partir de un conjunto de features *X* (que pueden ser uno, dos, o muchos más) tomando como muestra un conjunto de instancias.
#
# Vamos a comenzar introduciendo un dataset sintético de dos features y dos clases. Y trataremos de aprender a clasificarlo usando nuestro primer modelo, Árbol de Decisión.
#
# ### Modelo: Árbol de decisión
#
# El primer modelo de clasificación que vamos a utilizar es un Árbol de decisión.
#
# Dadas varias instancias con un determinados grupo de features **X** y unas determinadas etiquetas objetivo **y**, el árbol de desición aprende AUTOMÁTICAMENTE reglas (de mayor o menor) sobre cada feature de manera de poder decidir que etiqueta le corresponde a cada uno.
#
# ### Ejemplo demostrativo
# Vamos a generar automáticamente un grupo de 1000 instancias con features llamados *x1* y *x2* - agrupados en una única variable `X`- a los cuales les vamos a asignar una etiqueta `y`, la cual puede valer 0 y 1.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
# Función que nos ayuda a graficar
# No hace falta que comprendan este bloque de código.

def visualize_classifier(model, X, y, ax=None, cmap='rainbow'):
    ax = ax or plt.gca()

    # Plot the training points
    ax.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=cmap,
               clim=(y.min(), y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()

    xx, yy = np.meshgrid(np.linspace(*xlim, num=200),
                         np.linspace(*ylim, num=200))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)

    # Create a color plot with the results
    n_classes = len(np.unique(y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3,
                           levels=np.arange(n_classes + 1) - 0.5,
                           cmap=cmap, clim=(y.min(), y.max()),
                           zorder=1)

    ax.set(xlim=xlim, ylim=ylim)

# %% [markdown]
# ### Generamos nuestro Dataset
# Para crear nuestro DataSet utilizaremos un función **sklearn.datasets.make_blobs** que tiene la librería **Scikit-learn**. Ésta permite la generación de "gotas" (clusters) de datos con distribución gausiana e isotrópica.
# * Es posible definir el número de puntos a generar, el número de clusters, especificar los centros, la desviación estandar de los clusters generados, etc.
#
# Por ejemplo, podemos generar dos clusters de 200 y 100 puntos cada uno, con una desviación estándar de 1.0 y 0.5 respectivamente, y centros en las coordenadas (0, 0) y (1, 1) respectivamente de la siguiente forma:
#
# Comenzamos importando las librerías:
# * from sklearn.datasets import make_blobs
# * import seaborn as sns
#
# Generamos los puntos con la función make_blobs y mostramos el resultado:

# %%
from sklearn.datasets import make_blobs
import seaborn as sns
X, y1 = make_blobs(n_samples = [200, 100], random_state = 0, cluster_std = [1.0, 0.5], centers = [(0, 0), (1, 1)])
fig, ax = plt.subplots(figsize = (10, 7))
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y1)
# Out:
# <Axes: >

# %% [markdown]
# Ahora generamos el dataset para este notebook.

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=1000, centers=2, random_state=0, cluster_std=1.3)

# %% [markdown]
# Ahora vamos a graficar las diferentes instancias que generamos como puntos en el plano (x1,x2) y les asignamos un color distinto segun cual sea su etiqueta `y`:

# %%
plt.subplots(figsize = (10, 7))
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='rainbow')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %% [markdown]
# Si queremos entrenar un árbol de decisión para clasificar nuestras instancias, primero debemos crear un objeto correspondiente al modelo. Este objeto será de de la clase **DecisionTreeClassifier**, la cual importamos desde la librería scikit-learn:

# %%
from sklearn.tree import DecisionTreeClassifier

# Creamos un objeto arbol
TreeClassifier = DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# Una vez que nuestro modelo fue creado, precisamos entrenarlo sobre nuestros datos. Esto lo logramos con el método `fit` que poseen todas las clases correspondientes a modelos de scikit-learn.

# %%
TreeClassifier.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# La función que definimos arriba nos permite explorar cómo es el dominio de decisión de nuestro arbol una vez que lo entrenamos.

# %%
plt.subplots(figsize = (10, 7))
visualize_classifier(TreeClassifier, X, y)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14580\3665341031.py:21: UserWarning: The following kwargs were not used by contour: 'clim'
#   contours = ax.contourf(xx, yy, Z, alpha=0.3,

# %% [markdown]
# En este gráfico aquellos puntos (instancias) que queden sobre un fondo de su mismo color son aquellos que están bien clasificados por el modelo. Esto quiere decir que que si usamos el modelo para calificar su etiqueta 'y' a partir de sus coordenadas 'x1' y 'x2', este nos daría la misma etiqueta original del punto.
#
# En cambio, aquellos puntos que queda sobre un fondo de otro color son puntos para los cuales el modelo nos estaría dando una etiqueta distinta a la etiqueta original de esa instancia.

# %% [markdown]
# Veamos graficamente el árbol de decisión que el algoritmo armó:

# %%
from sklearn import tree
tree.plot_tree(TreeClassifier.fit(X, y))
# Out:
# [Text(0.5, 0.875, 'X[1] <= 2.396\ngini = 0.5\nsamples = 1000\nvalue = [500, 500]'),
#  Text(0.25, 0.625, 'X[1] <= 1.92\ngini = 0.144\nsamples = 475\nvalue = [37, 438]'),
#  Text(0.125, 0.375, 'X[0] <= 0.472\ngini = 0.07\nsamples = 415\nvalue = [15, 400]'),
#  Text(0.0625, 0.125, 'gini = 0.273\nsamples = 43\nvalue = [7, 36]'),
#  Text(0.1875, 0.125, 'gini = 0.042\nsamples = 372\nvalue = [8, 364]'),
#  Text(0.375, 0.375, 'X[0] <= 1.814\ngini = 0.464\nsamples = 60\nvalue = [22, 38]'),
#  Text(0.3125, 0.125, 'gini = 0.496\nsamples = 35\nvalue = [19, 16]'),
#  Text(0.4375, 0.125, 'gini = 0.211\nsamples = 25\nvalue = [3, 22]'),
#  Text(0.75, 0.625, 'X[1] <= 3.554\ngini = 0.208\nsamples = 525\nvalue = [463, 62]'),
#  Text(0.625, 0.375, 'X[0] <= 0.745\ngini = 0.454\nsamples = 155\nvalue = [101, 54]'),
#  Text(0.5625, 0.125, 'gini = 0.251\nsamples = 68\nvalue = [58, 10]'),
#  Text(0.6875, 0.125, 'gini = 0.5\nsamples = 87\nvalue = [43, 44]'),
#  Text(0.875, 0.375, 'X[1] <= 3.878\ngini = 0.042\nsamples = 370\nvalue = [362, 8]'),
#  Text(0.8125, 0.125, 'gini = 0.204\nsamples = 52\nvalue = [46, 6]'),
#  Text(0.9375, 0.125, 'gini = 0.012\nsamples = 318\nvalue = [316, 2]')]

# %% [markdown]
# La información de cada nodo es la siguiente:
#
# * **condición**: si es un nodo donde se toma alguna decisión
# * **gini**: es una medida de impureza. A continuación veremos cómo se calcula
# * **samples**: número de muestras que satisfacen las condiciones necesarias para llegar a este nodo
# * **value**: cuántas muestras de cada clase llegan a este nodo
# * **class**: qué clase se le asigna a las muestras que llegan a este nodo

# %% [markdown]
# Nos podríamos preguntar luego: ¿cuál es el porcentaje de instancias bien clasificadas por el modelo?
#
# Para responder esto usaremos el método `predict`. Este método nos indica la etiqueta asignada por el modelo a cada instancia del set de entrenamiento. Luego con la función `accuracy_score` podemos calcular el porcentaje de aciertos que obtenemos al comparar nuestra predicción `y_pred` contra la clase original `y`.

# %%
from sklearn.metrics import accuracy_score

# Predecimos sobre nuestro set de entrenamieto
y_pred = TreeClassifier.predict(X)

# Comaparamos con las etiquetas reales
accuracy_score(y_pred, y)
# Out:
# 0.905

# %%
import sklearn as sk
sk.metrics.confusion_matrix(y, y_pred)
# Out:
# array([[439,  61],
#        [ 34, 466]], dtype=int64)

# %% [markdown]
# **Para pensar y probar**:
# 1. ¿Qué ocurre si modifican el valor de `cluster_std` en la función `make_blobs`?¿En qué casos será más fácil - o difícil - la tarea de clasificación? Pruebe con los vaores 3 y 0.5.
# 2. ¿Qué ocurre si modifican el valor de `centers` en la función `make_blobs`?¿En qué cambia la formulación del problema de clasificación?

# %% [markdown]
# ## Ejercicio - Dataset del Titanic
#
#
# ### Problema a resolver
# El problema que nos planteamos es el siguiente: supongamos que tenemos el dataset de Titanic, donde conocemos varios datos de cada pasajero, incluído si sobrevivió o no al accidente. Pero nos dicen que se encontraron registros de nuevos pasajero, de los cuales se conocen todos los datos pero no saben si sobrevivieron. ¿Podremos generar un algoritmo que nos indique (en base a la información de los pasajeros que sí conocemos su estado) si esos otros pasajeros sobrevivieron o no?
#
# Como ven este problema es de clasificación: tenemos que decidir la categoría (sobrevivió o no) de cada instancia en base a ciertos datos.

# %% [markdown]
# ## Preprocesamiento
# Vamos a importar y limpiar nuesto dataset antes de empezar a analizarlo.

# %%
# Importamos el Dataset
df = pd.read_csv('../00_datasets/train.csv')
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Para trabajar en este problema, vamos a quedarnos solo con algunos de los features disponibles en el dataset.
#
# **Ejercicio**: descarte del dataset las columnas `Cabin`, `PassengerId`, `Name`, `Ticket`, `Embarked`.

# %%
df.drop(['Cabin','PassengerId','Name','Ticket','Embarked'], axis=1,inplace=True)

# %% [markdown]
# **Ejercicio:** ¿Cuántas instancias con valores faltantes quedan? Descarte del Dataset dichas instancias.

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# dtype: int64

# %%
df.dropna(inplace = True)

# %% [markdown]
# **Ejercicio:** Note que de los features restantes, solo uno es de tipo categórico. ¿Cuál es? Use la función `LabelEncoder` de scikit-learn para cambiarlo a una variables numérica.

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0           0       3    1  22.0      1      0   7.2500
# 1           1       1    0  38.0      1      0  71.2833
# 2           1       3    0  26.0      0      0   7.9250
# 3           1       1    0  35.0      1      0  53.1000
# 4           0       3    1  35.0      0      0   8.0500
# ..        ...     ...  ...   ...    ...    ...      ...
# 885         0       3    0  39.0      0      5  29.1250
# 886         0       2    1  27.0      0      0  13.0000
# 887         1       1    0  19.0      0      0  30.0000
# 889         1       1    1  26.0      0      0  30.0000
# 890         0       3    1  32.0      0      0   7.7500
#
# [714 rows x 7 columns]

# %% [markdown]
# ## Análisis exploratorio de datos
#
# Muy bien, ahora tenemos un dataset reducido, sólo con features numéricos y sin valores faltantes. Recordemos que nuestro objetivo es predecir si un pasajero sobrevivió o no. Por ende nuestra columna objetivo será `Survived`.
#
# El objetivo en esta pequeña exploración del dataset será saber cuales de los features (las columnas) serán de mayor utilidad para predecir si la persona sobrevivió o no.
#
# Primero, vemos que porcentaje de pasajeros sobrevivió:

# %%
sns.countplot(x='Survived', data=df) #equivelante a sns.countplot(df.Sex)
plt.show()

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    424
# 1    290
# Name: count, dtype: int64

# %%
# Calculamos el porcentaje numérico
cuenta_sobrevivientes = df['Survived'].value_counts()
porcentaje = 100*(cuenta_sobrevivientes.values[0]/df.shape[0])
print('Porcentaje de no sobrevivientes:',porcentaje)
# Out:
# Porcentaje de no sobrevivientes: 59.38375350140056

# %% [markdown]
# Tenemos que un 60% de los pasajeron no sobrevivieron. Es decir que, si ante la pregunta "¿Sobrevivió este pasajero?" nuestra respuesta fuese siempre "No", estaríamos acertando el 60% de las veces. Nuestro modelo tiene que desempeñarse mejor que esto.
#
# Vamos a explorar cuales de los features parecen, que nos pueden ayudar a decidir mejor si un pasajero sobrevivió o no. Para empezar, vamos a implementar un Árbol de decisión que solo tendrá dos variables de entrada, por lo tanto debemos elegir las dos columnas que nos parezcan más adecuadas. Veamos como correlacionan las variables del dataset:

# %%
# No tocar este código
def plot_corre_heatmap(corr):
    '''
    Definimos una función para ayudarnos a graficar un heatmap de correlación
    '''
    plt.figure(figsize=(12,10))
    sns.heatmap(corr, cbar = True,  square = False, annot=True, fmt= '.2f'
                ,annot_kws={'size': 15},cmap= 'coolwarm')
    plt.xticks(rotation = 45)
    plt.yticks(rotation = 45)
    # Arreglamos un pequeño problema de visualización
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show()

# %%
corr = df.corr()
plot_corre_heatmap(corr)

# %% [markdown]
# Mire con atención el gráfico anterior y recuerde que nuestra columna/fila a predecir es la primera ,`Survived`.
#
# **Ejercicio:** ¿Cuáles dos columnas eligiría para usar como variables predictoras en el modelo? ¿Por qué?

# %% [markdown]
# ## Entrenamiento del Modelo y evaluación
#
# Veamos ahora que tan bien puede predecir el árbol de decisión sobre el dataset.
#
# **Ejercicio**: Crear un objeto de la clase `DecisionTreeClassifier` (que importamos desde `sklearn.tree`):

# %%
from sklearn.tree import DecisionTreeClassifier

# Creamos un objeto arbol
DecisionTreeClassifier = DecisionTreeClassifier()

# %% [markdown]
# **Ejercicio:** definir nuestras variables predictoras con las cuales vamos a entrenar el modelo, a las que llamaremos `x_train`. Usar las columas del dataset que elegimos del ejercicio anterior.

# %%
x_train = df[['Pclass','Sex']]

# %% [markdown]
# **Ejercicio:** definir el atributo objetivo que buscamos predecir. Lo llamaremos `y_train`:

# %%
y_train = df['Survived']

# %% [markdown]
# **Ejercicio:** entrenar el modelo.

# %%
DecisionTreeClassifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
tree.plot_tree(DecisionTreeClassifier.fit(x_train, y_train))
# Out:
# [Text(0.5, 0.875, 'X[1] <= 0.5\ngini = 0.482\nsamples = 714\nvalue = [424, 290]'),
#  Text(0.3, 0.625, 'X[0] <= 2.5\ngini = 0.37\nsamples = 261\nvalue = [64, 197]'),
#  Text(0.2, 0.375, 'X[0] <= 1.5\ngini = 0.107\nsamples = 159\nvalue = [9, 150]'),
#  Text(0.1, 0.125, 'gini = 0.068\nsamples = 85\nvalue = [3, 82]'),
#  Text(0.3, 0.125, 'gini = 0.149\nsamples = 74\nvalue = [6, 68]'),
#  Text(0.4, 0.375, 'gini = 0.497\nsamples = 102\nvalue = [55, 47]'),
#  Text(0.7, 0.625, 'X[0] <= 1.5\ngini = 0.326\nsamples = 453\nvalue = [360, 93]'),
#  Text(0.6, 0.375, 'gini = 0.478\nsamples = 101\nvalue = [61, 40]'),
#  Text(0.8, 0.375, 'X[0] <= 2.5\ngini = 0.256\nsamples = 352\nvalue = [299, 53]'),
#  Text(0.7, 0.125, 'gini = 0.257\nsamples = 99\nvalue = [84, 15]'),
#  Text(0.9, 0.125, 'gini = 0.255\nsamples = 253\nvalue = [215, 38]')]

# %% [markdown]
# Nuestro árbol ya está entrenado.
#
# Ahora vamos a ver cuales son las etiquetas que el modelo le asigna a cada una de las instancias. Es decir vamos a pasarle al modelo el valor de `Pclass` y de `Sex`, y éste nos dirá si el pasajero sobrevivió o no (`y_pred`). Estas son las predicciones del modelo, pero nosotros conocemos además el verdadero paradero de estos pasajeros (son los valores de `y_train`).
#
# Comparando ambos valores (`y_pred` e `y_train`) podemos conocer el *accuracy* (porcentaje de aciertos) de nuestro modelo sobre el training set.

# %%
from sklearn.metrics import accuracy_score

# Predecimos sobre nuestro set de entrenamieto
y_pred = DecisionTreeClassifier.predict(x_train)

# Comaparamos con las etiquetas reales
accuracy_score(y_pred,y_train)
# Out:
# 0.7913165266106442

# %% [markdown]
# Obtuvimos un 80%, apenas un 20% más.
#
# Pongamos ahora toda la carne al asador, y pasémosle al modelo todos los datos que tenemos disponibles en el dataset, no sólo dos columnas. Veamos si esto mejora las predicciones del mismo.

# %%
x_train = df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']]
y_train = df['Survived']

# %%
DecisionTreeClassifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
tree.plot_tree(DecisionTreeClassifier.fit(x_train, y_train))
# Out:
# [Text(0.34958203125, 0.9782608695652174, 'X[1] <= 0.5\ngini = 0.482\nsamples = 714\nvalue = [424, 290]'),
#  Text(0.19025, 0.9347826086956522, 'X[0] <= 2.5\ngini = 0.37\nsamples = 261\nvalue = [64, 197]'),
#  Text(0.084, 0.8913043478260869, 'X[2] <= 2.5\ngini = 0.107\nsamples = 159\nvalue = [9, 150]'),
#  Text(0.064, 0.8478260869565217, 'X[4] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.056, 0.8043478260869565, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.072, 0.8043478260869565, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.104, 0.8478260869565217, 'X[5] <= 28.856\ngini = 0.097\nsamples = 157\nvalue = [8, 149]'),
#  Text(0.088, 0.8043478260869565, 'X[5] <= 28.231\ngini = 0.185\nsamples = 68\nvalue = [7, 61]'),
#  Text(0.08, 0.7608695652173914, 'X[2] <= 56.0\ngini = 0.163\nsamples = 67\nvalue = [6, 61]'),
#  Text(0.056, 0.717391304347826, 'X[3] <= 0.5\ngini = 0.142\nsamples = 65\nvalue = [5, 60]'),
#  Text(0.032, 0.6739130434782609, 'X[5] <= 13.25\ngini = 0.087\nsamples = 44\nvalue = [2, 42]'),
#  Text(0.024, 0.6304347826086957, 'X[5] <= 12.825\ngini = 0.153\nsamples = 24\nvalue = [2, 22]'),
#  Text(0.016, 0.5869565217391305, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.032, 0.5869565217391305, 'X[2] <= 26.0\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.016, 0.5434782608695652, 'X[4] <= 1.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.008, 0.5, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.024, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.048, 0.5434782608695652, 'X[2] <= 37.0\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.04, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.056, 0.5, 'X[2] <= 39.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.048, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.064, 0.45652173913043476, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04, 0.6304347826086957, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.08, 0.6739130434782609, 'X[2] <= 25.0\ngini = 0.245\nsamples = 21\nvalue = [3, 18]'),
#  Text(0.072, 0.6304347826086957, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.088, 0.6304347826086957, 'X[2] <= 27.5\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.072, 0.5869565217391305, 'X[5] <= 17.429\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.064, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08, 0.5434782608695652, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.104, 0.5869565217391305, 'X[2] <= 43.0\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.096, 0.5434782608695652, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.112, 0.5434782608695652, 'X[4] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.104, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.104, 0.717391304347826, 'X[0] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.096, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.112, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.096, 0.7608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12, 0.8043478260869565, 'X[4] <= 1.5\ngini = 0.022\nsamples = 89\nvalue = [1, 88]'),
#  Text(0.112, 0.7608695652173914, 'gini = 0.0\nsamples = 74\nvalue = [0, 74]'),
#  Text(0.128, 0.7608695652173914, 'X[2] <= 24.5\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.12, 0.717391304347826, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.136, 0.717391304347826, 'X[2] <= 28.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.128, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.144, 0.6739130434782609, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.2965, 0.8913043478260869, 'X[5] <= 20.8\ngini = 0.497\nsamples = 102\nvalue = [55, 47]'),
#  Text(0.243, 0.8478260869565217, 'X[2] <= 16.5\ngini = 0.494\nsamples = 79\nvalue = [35, 44]'),
#  Text(0.192, 0.8043478260869565, 'X[2] <= 14.75\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.184, 0.7608695652173914, 'X[2] <= 7.0\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.168, 0.717391304347826, 'X[5] <= 10.798\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.16, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.176, 0.6739130434782609, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.2, 0.717391304347826, 'X[5] <= 12.848\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.192, 0.6739130434782609, 'X[3] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.184, 0.6304347826086957, 'X[5] <= 7.542\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.176, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.192, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.208, 0.6739130434782609, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2, 0.7608695652173914, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.294, 0.8043478260869565, 'X[2] <= 36.5\ngini = 0.499\nsamples = 59\nvalue = [31, 28]'),
#  Text(0.278, 0.7608695652173914, 'X[4] <= 1.5\ngini = 0.499\nsamples = 52\nvalue = [25, 27]'),
#  Text(0.27, 0.717391304347826, 'X[2] <= 32.5\ngini = 0.498\nsamples = 47\nvalue = [25, 22]'),
#  Text(0.262, 0.6739130434782609, 'X[5] <= 7.888\ngini = 0.491\nsamples = 44\nvalue = [25, 19]'),
#  Text(0.216, 0.6304347826086957, 'X[2] <= 28.25\ngini = 0.469\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.208, 0.5869565217391305, 'X[2] <= 18.5\ngini = 0.408\nsamples = 14\nvalue = [4, 10]'),
#  Text(0.18, 0.5434782608695652, 'X[5] <= 7.123\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.172, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.188, 0.5, 'X[5] <= 7.635\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.18, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.196, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.236, 0.5434782608695652, 'X[2] <= 24.0\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.22, 0.5, 'X[2] <= 21.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.212, 0.45652173913043476, 'X[5] <= 7.802\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.204, 0.41304347826086957, 'X[5] <= 7.7\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.196, 0.3695652173913043, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.212, 0.3695652173913043, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.22, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.228, 0.45652173913043476, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.252, 0.5, 'X[2] <= 25.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.244, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.26, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.224, 0.5869565217391305, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.308, 0.6304347826086957, 'X[2] <= 23.5\ngini = 0.436\nsamples = 28\nvalue = [19, 9]'),
#  Text(0.284, 0.5869565217391305, 'X[2] <= 19.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.276, 0.5434782608695652, 'X[5] <= 12.148\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.268, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.284, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.292, 0.5434782608695652, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.332, 0.5869565217391305, 'X[3] <= 0.5\ngini = 0.492\nsamples = 16\nvalue = [9, 7]'),
#  Text(0.308, 0.5434782608695652, 'X[2] <= 25.0\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.3, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.316, 0.5, 'X[5] <= 7.91\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.308, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.324, 0.45652173913043476, 'X[2] <= 28.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.316, 0.41304347826086957, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.332, 0.41304347826086957, 'X[5] <= 8.673\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.324, 0.3695652173913043, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.34, 0.3695652173913043, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.356, 0.5434782608695652, 'X[5] <= 19.262\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.348, 0.5, 'X[2] <= 24.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.34, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.356, 0.45652173913043476, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.364, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.278, 0.6739130434782609, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.286, 0.717391304347826, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.31, 0.7608695652173914, 'X[2] <= 55.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.302, 0.717391304347826, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.318, 0.717391304347826, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.35, 0.8478260869565217, 'X[2] <= 5.5\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(0.334, 0.8043478260869565, 'X[2] <= 3.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.326, 0.7608695652173914, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.342, 0.7608695652173914, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.366, 0.8043478260869565, 'X[4] <= 4.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.358, 0.7608695652173914, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.374, 0.7608695652173914, 'X[2] <= 38.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.366, 0.717391304347826, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.382, 0.717391304347826, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5089140625, 0.9347826086956522, 'X[2] <= 6.5\ngini = 0.326\nsamples = 453\nvalue = [360, 93]'),
#  Text(0.398, 0.8913043478260869, 'X[3] <= 2.5\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(0.39, 0.8478260869565217, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.406, 0.8478260869565217, 'X[4] <= 1.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.398, 0.8043478260869565, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.414, 0.8043478260869565, 'X[2] <= 3.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.406, 0.7608695652173914, 'X[2] <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.398, 0.717391304347826, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.414, 0.717391304347826, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.422, 0.7608695652173914, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.619828125, 0.8913043478260869, 'X[0] <= 1.5\ngini = 0.295\nsamples = 429\nvalue = [352, 77]'),
#  Text(0.484, 0.8478260869565217, 'X[2] <= 53.0\ngini = 0.473\nsamples = 99\nvalue = [61, 38]'),
#  Text(0.446, 0.8043478260869565, 'X[5] <= 25.938\ngini = 0.496\nsamples = 77\nvalue = [42, 35]'),
#  Text(0.438, 0.7608695652173914, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.454, 0.7608695652173914, 'X[5] <= 27.135\ngini = 0.5\nsamples = 72\nvalue = [37, 35]'),
#  Text(0.438, 0.717391304347826, 'X[2] <= 43.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.43, 0.6739130434782609, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.446, 0.6739130434782609, 'X[2] <= 46.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.438, 0.6304347826086957, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.454, 0.6304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.47, 0.717391304347826, 'X[2] <= 17.5\ngini = 0.484\nsamples = 61\nvalue = [36, 25]'),
#  Text(0.462, 0.6739130434782609, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.478, 0.6739130434782609, 'X[2] <= 22.5\ngini = 0.476\nsamples = 59\nvalue = [36, 23]'),
#  Text(0.47, 0.6304347826086957, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.486, 0.6304347826086957, 'X[2] <= 27.5\ngini = 0.489\nsamples = 54\nvalue = [31, 23]'),
#  Text(0.458, 0.5869565217391305, 'X[5] <= 77.965\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.45, 0.5434782608695652, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.466, 0.5434782608695652, 'X[3] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.458, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.474, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.514, 0.5869565217391305, 'X[5] <= 115.442\ngini = 0.463\nsamples = 44\nvalue = [28, 16]'),
#  Text(0.498, 0.5434782608695652, 'X[5] <= 30.25\ngini = 0.426\nsamples = 39\nvalue = [27, 12]'),
#  Text(0.49, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.506, 0.5, 'X[5] <= 32.51\ngini = 0.457\nsamples = 34\nvalue = [22, 12]'),
#  Text(0.498, 0.45652173913043476, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.514, 0.45652173913043476, 'X[3] <= 0.5\ngini = 0.412\nsamples = 31\nvalue = [22, 9]'),
#  Text(0.494, 0.41304347826086957, 'X[2] <= 29.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.486, 0.3695652173913043, 'X[5] <= 41.3\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.478, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.494, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.502, 0.3695652173913043, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.534, 0.41304347826086957, 'X[2] <= 49.5\ngini = 0.472\nsamples = 21\nvalue = [13, 8]'),
#  Text(0.526, 0.3695652173913043, 'X[2] <= 47.0\ngini = 0.494\nsamples = 18\nvalue = [10, 8]'),
#  Text(0.51, 0.32608695652173914, 'X[4] <= 0.5\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.502, 0.2826086956521739, 'X[2] <= 43.0\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.494, 0.2391304347826087, 'X[5] <= 86.085\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.486, 0.1956521739130435, 'X[5] <= 61.8\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.478, 0.15217391304347827, 'X[5] <= 52.277\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.47, 0.10869565217391304, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.486, 0.10869565217391304, 'X[2] <= 34.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.478, 0.06521739130434782, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.494, 0.06521739130434782, 'X[2] <= 39.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.486, 0.021739130434782608, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.502, 0.021739130434782608, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.494, 0.15217391304347827, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.502, 0.1956521739130435, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.51, 0.2391304347826087, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.518, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.542, 0.32608695652173914, 'X[4] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.534, 0.2826086956521739, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.55, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.542, 0.3695652173913043, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.53, 0.5434782608695652, 'X[2] <= 37.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.522, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.538, 0.5, 'X[3] <= 1.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.53, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.546, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.522, 0.8043478260869565, 'X[2] <= 75.5\ngini = 0.236\nsamples = 22\nvalue = [19, 3]'),
#  Text(0.514, 0.7608695652173914, 'X[5] <= 35.077\ngini = 0.172\nsamples = 21\nvalue = [19, 2]'),
#  Text(0.506, 0.717391304347826, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.522, 0.717391304347826, 'X[5] <= 42.502\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.514, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.53, 0.6739130434782609, 'X[3] <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.522, 0.6304347826086957, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.538, 0.6304347826086957, 'X[2] <= 62.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.53, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.546, 0.5869565217391305, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.53, 0.7608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.75565625, 0.8478260869565217, 'X[2] <= 13.0\ngini = 0.208\nsamples = 330\nvalue = [291, 39]'),
#  Text(0.6065, 0.8043478260869565, 'X[3] <= 2.0\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.5985, 0.7608695652173914, 'X[2] <= 10.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.5905, 0.717391304347826, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6065, 0.717391304347826, 'X[3] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5985, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6145, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6145, 0.7608695652173914, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.9048125, 0.8043478260869565, 'X[5] <= 51.698\ngini = 0.196\nsamples = 318\nvalue = [283, 35]'),
#  Text(0.833625, 0.7608695652173914, 'X[2] <= 32.25\ngini = 0.186\nsamples = 309\nvalue = [277, 32]'),
#  Text(0.74325, 0.717391304347826, 'X[2] <= 30.75\ngini = 0.222\nsamples = 204\nvalue = [178, 26]'),
#  Text(0.6305, 0.6739130434782609, 'X[0] <= 2.5\ngini = 0.192\nsamples = 186\nvalue = [166, 20]'),
#  Text(0.578, 0.6304347826086957, 'X[5] <= 11.0\ngini = 0.05\nsamples = 39\nvalue = [38, 1]'),
#  Text(0.57, 0.5869565217391305, 'X[2] <= 21.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.562, 0.5434782608695652, 'X[2] <= 17.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.554, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.57, 0.5, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.578, 0.5434782608695652, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.586, 0.5869565217391305, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(0.683, 0.6304347826086957, 'X[2] <= 26.5\ngini = 0.225\nsamples = 147\nvalue = [128, 19]'),
#  Text(0.61, 0.5869565217391305, 'X[5] <= 2.006\ngini = 0.188\nsamples = 114\nvalue = [102, 12]'),
#  Text(0.594, 0.5434782608695652, 'X[2] <= 22.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.586, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.602, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.626, 0.5434782608695652, 'X[5] <= 7.133\ngini = 0.177\nsamples = 112\nvalue = [101, 11]'),
#  Text(0.618, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.634, 0.5, 'X[5] <= 7.227\ngini = 0.192\nsamples = 102\nvalue = [91, 11]'),
#  Text(0.6, 0.45652173913043476, 'X[2] <= 24.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.592, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.608, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.668, 0.45652173913043476, 'X[2] <= 20.25\ngini = 0.165\nsamples = 99\nvalue = [90, 9]'),
#  Text(0.624, 0.41304347826086957, 'X[5] <= 8.104\ngini = 0.236\nsamples = 44\nvalue = [38, 6]'),
#  Text(0.6, 0.3695652173913043, 'X[5] <= 7.91\ngini = 0.34\nsamples = 23\nvalue = [18, 5]'),
#  Text(0.576, 0.32608695652173914, 'X[2] <= 19.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.568, 0.2826086956521739, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.584, 0.2826086956521739, 'X[5] <= 7.542\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.576, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.592, 0.2391304347826087, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.624, 0.32608695652173914, 'X[3] <= 0.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.616, 0.2826086956521739, 'X[2] <= 19.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.608, 0.2391304347826087, 'X[2] <= 17.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.6, 0.1956521739130435, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.616, 0.1956521739130435, 'X[2] <= 18.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.608, 0.15217391304347827, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.624, 0.15217391304347827, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.624, 0.2391304347826087, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.632, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.648, 0.3695652173913043, 'X[2] <= 19.5\ngini = 0.091\nsamples = 21\nvalue = [20, 1]'),
#  Text(0.64, 0.32608695652173914, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.656, 0.32608695652173914, 'X[3] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.648, 0.2826086956521739, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.664, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.712, 0.41304347826086957, 'X[5] <= 18.294\ngini = 0.103\nsamples = 55\nvalue = [52, 3]'),
#  Text(0.696, 0.3695652173913043, 'X[5] <= 7.798\ngini = 0.074\nsamples = 52\nvalue = [50, 2]'),
#  Text(0.688, 0.32608695652173914, 'X[5] <= 7.758\ngini = 0.18\nsamples = 20\nvalue = [18, 2]'),
#  Text(0.68, 0.2826086956521739, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.696, 0.2826086956521739, 'X[2] <= 21.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.68, 0.2391304347826087, 'X[5] <= 7.785\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.672, 0.1956521739130435, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.688, 0.1956521739130435, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.712, 0.2391304347826087, 'X[3] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.704, 0.1956521739130435, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.72, 0.1956521739130435, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.704, 0.32608695652173914, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(0.728, 0.3695652173913043, 'X[5] <= 19.681\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.72, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.736, 0.32608695652173914, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.756, 0.5869565217391305, 'X[2] <= 27.5\ngini = 0.334\nsamples = 33\nvalue = [26, 7]'),
#  Text(0.728, 0.5434782608695652, 'X[5] <= 7.846\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.72, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.736, 0.5, 'X[5] <= 8.279\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.728, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.744, 0.45652173913043476, 'X[3] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.736, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.752, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.784, 0.5434782608695652, 'X[2] <= 28.75\ngini = 0.245\nsamples = 28\nvalue = [24, 4]'),
#  Text(0.776, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.792, 0.5, 'X[5] <= 9.492\ngini = 0.36\nsamples = 17\nvalue = [13, 4]'),
#  Text(0.776, 0.45652173913043476, 'X[2] <= 29.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.768, 0.41304347826086957, 'X[5] <= 7.973\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.76, 0.3695652173913043, 'X[5] <= 7.885\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.752, 0.32608695652173914, 'X[5] <= 7.763\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.744, 0.2826086956521739, 'X[5] <= 7.398\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.736, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.752, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.76, 0.2826086956521739, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.768, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.776, 0.3695652173913043, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.784, 0.41304347826086957, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.808, 0.45652173913043476, 'X[3] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.816, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.856, 0.6739130434782609, 'X[5] <= 7.815\ngini = 0.444\nsamples = 18\nvalue = [12, 6]'),
#  Text(0.848, 0.6304347826086957, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.864, 0.6304347826086957, 'X[5] <= 7.875\ngini = 0.48\nsamples = 15\nvalue = [9, 6]'),
#  Text(0.856, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.872, 0.5869565217391305, 'X[4] <= 0.5\ngini = 0.459\nsamples = 14\nvalue = [9, 5]'),
#  Text(0.864, 0.5434782608695652, 'X[5] <= 20.925\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.856, 0.5, 'X[2] <= 31.5\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.84, 0.45652173913043476, 'X[0] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.832, 0.41304347826086957, 'X[5] <= 11.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.824, 0.3695652173913043, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.84, 0.3695652173913043, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.848, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.872, 0.45652173913043476, 'X[5] <= 8.206\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.864, 0.41304347826086957, 'X[5] <= 7.988\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.856, 0.3695652173913043, 'X[5] <= 7.91\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.848, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.864, 0.32608695652173914, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.872, 0.3695652173913043, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.88, 0.41304347826086957, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.872, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.88, 0.5434782608695652, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.924, 0.717391304347826, 'X[5] <= 7.91\ngini = 0.108\nsamples = 105\nvalue = [99, 6]'),
#  Text(0.916, 0.6739130434782609, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(0.932, 0.6739130434782609, 'X[5] <= 7.988\ngini = 0.151\nsamples = 73\nvalue = [67, 6]'),
#  Text(0.912, 0.6304347826086957, 'X[3] <= 1.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.904, 0.5869565217391305, 'X[2] <= 41.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.896, 0.5434782608695652, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.912, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.92, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.952, 0.6304347826086957, 'X[2] <= 61.0\ngini = 0.109\nsamples = 69\nvalue = [65, 4]'),
#  Text(0.936, 0.5869565217391305, 'X[5] <= 13.25\ngini = 0.087\nsamples = 66\nvalue = [63, 3]'),
#  Text(0.928, 0.5434782608695652, 'X[5] <= 12.938\ngini = 0.157\nsamples = 35\nvalue = [32, 3]'),
#  Text(0.904, 0.5, 'X[2] <= 44.5\ngini = 0.08\nsamples = 24\nvalue = [23, 1]'),
#  Text(0.896, 0.45652173913043476, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.912, 0.45652173913043476, 'X[2] <= 46.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.904, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.92, 0.41304347826086957, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.952, 0.5, 'X[2] <= 45.0\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.944, 0.45652173913043476, 'X[2] <= 40.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.936, 0.41304347826086957, 'X[2] <= 35.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.928, 0.3695652173913043, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.944, 0.3695652173913043, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.952, 0.41304347826086957, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.96, 0.45652173913043476, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.944, 0.5434782608695652, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.968, 0.5869565217391305, 'X[2] <= 64.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.96, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.976, 0.5434782608695652, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.976, 0.7608695652173914, 'X[0] <= 2.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.968, 0.717391304347826, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.984, 0.717391304347826, 'X[2] <= 30.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.976, 0.6739130434782609, 'X[2] <= 27.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.968, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.984, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.992, 0.6739130434782609, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]

# %%
# Predecimos sobre nuestro set de entrenamieto
y_pred = DecisionTreeClassifier.predict(x_train)

# Comaparamos con las etiquetas reales
accuracy_score(y_pred,y_train)
# Out:
# 0.9859943977591037

# %% [markdown]
# ¡Ahora sí tenemos una mejora sustancial
